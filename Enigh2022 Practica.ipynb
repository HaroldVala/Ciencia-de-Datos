# %% [markdown]
# # Liberias

# %%
import pandas as pd

# %% [markdown]
# # Archivo

# %%
base_df = pd.read_csv("gastoshogar.csv")

# %% [markdown]
# # Exploracion de datos

# %%
base_df.shape
# Out:
# (5075174, 31)

# %%
base_df.dtypes
# Out:
# folioviv       int64
# foliohog       int64
# clave         object
# tipo_gasto    object
# mes_dia        int64
# forma_pag1     int64
# forma_pag2     int64
# forma_pag3     int64
# lugar_comp     int64
# orga_inst      int64
# frecuencia     int64
# fecha_adqu     int64
# fecha_pago     int64
# cantidad      object
# gasto         object
# pago_mp       object
# costo         object
# inmujer       object
# inst_1        object
# inst_2        object
# num_meses     object
# num_pagos     object
# ultim_pago    object
# gasto_tri     object
# gasto_nm      object
# gas_nm_tri    object
# imujer_tri    object
# entidad        int64
# est_dis        int64
# upm            int64
# factor         int64
# dtype: object

# %%
base_df.head(10)
# Out:
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100005002         1  A004         G1     1109           1           0
# 1  100005002         1  A015         G1     1113           1           0
# 2  100005002         1  A019         G1     1113           1           0
# 3  100005002         1  A052         G1     1113           1           0
# 4  100005002         1  A075         G1     1110           1           0
# 5  100005002         1  A111         G1     1112           1           0
# 6  100005002         1  A112         G1     1112           1           0
# 7  100005002         1  A113         G1     1112           1           0
# 8  100005002         1  A124         G1     1112           1           0
# 9  100005002         1  A127         G1     1112           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  num_pagos  ultim_pago  gasto_tri  \
# 0           0           5          0  ...                            308.57
# ...

# %%
base_df
# Out:
#            folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  \
# 0         100005002         1  A004         G1     1109           1
# 1         100005002         1  A015         G1     1113           1
# 2         100005002         1  A019         G1     1113           1
# 3         100005002         1  A052         G1     1113           1
# 4         100005002         1  A075         G1     1110           1
# ...             ...       ...   ...        ...      ...         ...
# 5075169  3260797912         1  L005         G1        0           1
# 5075170  3260797912         1  R001         G1        0           1
# 5075171  3260797912         1  R004         G1        0           1
# 5075172  3260797912         1  R008         G1        0           1
# 5075173  3260797912         1  R012         G1        0           1
#
#          forma_pag2  forma_pag3  lugar_comp  orga_inst  ...  num_pagos  \
# 0                 0           0           5          0  ...
# ...

# %% [markdown]
# # Gasto por Trimestre

# %%
# Out:
# count     5075174
# unique      23754
# top
# freq       414394
# Name: gasto_tri, dtype: object
